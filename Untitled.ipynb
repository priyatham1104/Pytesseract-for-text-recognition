# %%
# !pip install pytesseract

# %%
# !pip3 install jedi==0.17.2

# %%
import cv2
import pytesseract
from pytesseract import Output
import os
import re

# %%
dir = os.getcwd()
dir1 = dir + "/images/"
dir2 = dir + "/images recognized/"
dir3 = dir + "/text recognized/"

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Users\ggp\Tesseract-OCR\tesseract.exe"

# %%
from pytesseract import image_to_string 
from PIL import Image
dir = os.getcwd()
dir1 = dir + "/images/"
os.chdir(dir1)
images = os.listdir()
for image in images:
    print(image)
#     image = str(img)
#     img = cv2.imread(image)
#     cv2.waitKey(0)
    text =  image_to_string(Image.open(image))
    os.chdir(dir3)
    with open(image + str('.txt'), mode = 'w') as f:
        f.write(text)
    os.chdir(dir1)
# Out:
# 1000.png
# 1001.png
# 1002.png
# 1003.png
# 1004.png
# 1005.png
# 1006.png
# 1007.png
# 1008.png
# 1009.png
# 1010.png
# 1011.png
# 1012.png
# 1013.png
# 1014.png
# 1015.png
# 1016.png
# 1017.png
# 1018.png
# 1020.png
# 1023.png
# 1024.png
# 1025.png
# 1026.png
# 1027.png
# 1028.png
# 1029.png
# 1030.png
# 1031.png
# 1032.png
# 1033.png
# 1034.png
# 1035.png
# 1036.png
# 1037.png
# 1038.png
# 1039.png
# 1040.png
# 1041.png
# 1042.png
# 1043.png
# 1044.png
# 1045.png
# 1046.png
# 1052.png
# 1053.png
# 1054.png
# 1055.png
# 1056.png
# 1057.png
# 1058.png
# 1059.png
# 1060.png
# 1061.png
# 1062.png
# 1063.png
# 1064.png
# 1065.png
# 1066.png
# 1067.png
# 1068.png
# 1069.png
# 1070.png
# 1071.png
# 1072.png
# 1073.png
# 1074.png
# 1075.png
# 1076.png
# 1077.png
# 1078.png
# 1079.png
# 1080.png
# 1081.png
# 1082.png
# 1083.png
# 1084.png
# 1085.png
# 1086.png
# 1087.png
# 1088.png
# 1089.png
# 1090.png
# 1091.png
# 1092.png
# 1093.png
# 1094.png
# 1095.png
# 1096.png
# 1097.png
# ...

# %%
print(d['text'])
# Out:
# ['', '', '', '', '  ', '', '', '', 'Wilhelm', 'Hoyer', 'GmbH', '&', 'Co.', 'KG', '', 'MineralélgroBhandel', '', 'Rudolf-Diesel-str.', '1', '', '', '21374', 'Visselhovede', '', '', '', 'W.', 'Hoyer', 'GmbH', '&', 'Co.KG,', '27374', 'Visselhovede', '', '', '', 'Firma', 'E', '', 'Bauer', 'Spezialtiefbau', 'GmbH', '', '', '', 'BAUER-Str.', '1', '', '', '', '86529', 'Schrobenhausen', '', '', '', 'An:', 'Bauer', 'Spezialtiefbau', 'GmbH', '(344064)', '', '', 'Kst.:', '03023706830', '', '', 'A26/A7,', 'Siiderelbe,', 'BL', '3.2', '', '', 'Moorburger', 'str.', '', '', '21079', 'Hamburg', '', 'Zufahrt', 'Uber', 'die', 'Waltersdorfer', 'Str', '', 'zw.Waltershofer', 'Str.', 'und', 'A7,Lotsenpunkt', '100', '', '', '', 'artikel', 'Bezeichnung', '', '', '', 'Diesel', 'Premium', 'Plus', 'DIN', 'EN', '590', '', '', '', 'Koaplenentir:', 'Hoyer', 'Verwa:', '', 'Sitz', 'der', 'Gesellschaft:', 'Visselhdvede,', '', 'Geschaftsfihrer:', '', '', '', ' ', '', '', '', ' ', '', '', '', ' ', '', '   ', '', '   ',
# ...

# %%
dir = os.getcwd()
dir1 = dir + "/images/"
dir2 = dir + "/pytesseracr all boxes/"
os.chdir(dir1)
images = os.listdir()
# print(images)
for image in images:
    try:
        print(image)
    #     image = str(img)
        img = cv2.imread(image)
        pytesseract.pytesseract.tesseract_cmd = r"C:\Users\ggp\Tesseract-OCR\tesseract.exe"
        d = pytesseract.image_to_data(img, output_type=Output.DICT)
        n_boxes = len(d['level'])
        window_name = 'Image'

        # font
        font = cv2.FONT_HERSHEY_SIMPLEX

        # org
        # org = (50, 50)

        # fontScale
        fontScale = 0.5

        # Blue color in BGR
        color = (255, 0, 0)

        # Line thickness of 2 px
        thickness = 2
        for i in range(n_boxes):
    #         if((d['text'][i].lower().find("1871") != -1) or (d['text'][i].lower().find("august") != -1) or (d['text'][i].lower().find("ernst")!= -1)  or (d['text'][i].lower().find("1871") != -1)):
    #             print(d['text'][i])
            (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
            cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
            cv2.putText(img, d['text'][i],(x, y),font, fontScale,   (0, 0, 255), 2)
    #         cv2.putText(img, "Client: AUGUST ERNST",(200, 200),font, 2,   (0, 0, 255), 2)
            os.chdir(dir2)
            cv2.imwrite(image, img)
            os.chdir(dir1)
    except:
        print("Error in file" + str(image))
#         if((d['text'][i].lower().find("clariant") != -1)):
#             print(d['text'][i])
#             (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
#             cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
#             cv2.putText(img, d['text'][i],(x, y),font, fontScale,   (0, 0, 255), 2)
#             cv2.putText(img, "Client: CLARIANT",(200, 200),font, 2,   (0, 0, 255), 2)
#             os.chdir(dir_clariant)
#             cv2.imwrite(image, img)
#             os.chdir(dir1)
#         if((d['text'][i].lower().find("hoyer") != -1)):
#             print(d['text'][i])
#             (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
#             cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
#             cv2.putText(img, d['text'][i],(x, y),font, fontScale,   (0, 0, 255), 2)
#             cv2.putText(img, "Client: HOYER",(200, 200),font, 2,   (0, 0, 255), 2)
#             os.chdir(dir_hoyer)
#             cv2.imwrite(image, img)
#             os.chdir(dir1)
#         if((d['text'][i].lower().find("huesker") != -1)):
#             print(d['text'][i])
#             (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
#             cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
#             cv2.putText(img, d['text'][i],(x, y),font, fontScale,   (0, 0, 255), 2)
#             cv2.putText(img, "Client: HUESKER",(200, 200),font, 2,   (0, 0, 255), 2)
#             os.chdir(dir_huesker)
#             cv2.imwrite(image, img)
#             os.chdir(dir1)
#         if((d['text'][i].lower().find("pfreundt") != -1) or (d['text'][i].lower().find("einfach") != -1) or (d['text'][i].lower().find("besser") != -1)or (d['text'][i].lower().find("besser") != -1) ):
#             print(d['text'][i])
#             (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
#             cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
#             cv2.putText(img, d['text'][i],(x, y),font, fontScale,   (0, 0, 255), 2)
#             cv2.putText(img, "Client: PFREUNDT",(200, 200),font, 2,   (0, 0, 255), 2)
#             os.chdir(dir_pfreundt)
#             cv2.imwrite(image, img)
#             os.chdir(dir1)
#         if((d['text'][i].lower().find("baumetrial") != -1)or (d['text'][i].lower().find("thom") != -1)):
#             print(d['text'][i])
#             (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
#             cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
#             cv2.putText(img, d['text'][i],(x, y),font, fontScale,   (0, 0, 255), 2)
#             cv2.putText(img, "Client:Thom Gmbh" ,(200, 200),font, 2,   (0, 0, 255), 2)
#             os.chdir(dir_thom)
#             cv2.imwrite(image, img)
#             os.chdir(dir1)
#         else:
#             os.chdir(dir_none)
#             cv2.imwrite(image, img)
#             os.chdir(dir1)
            
# cv2.imshow("Img", img)
# cv2.waitKey(0)
#     cv2.imshow('img', img)
#     cv2.waitKey(0)
os.chdir(dir)
# Out:
# 1000.png
# 1001.png
# 1002.png
# 1003.png
# 1004.png
# 1005.png
# 1006.png
# 1007.png
# 1008.png
# 1009.png
# 1010.png
# 1011.png
# 1012.png
# 1013.png
# 1014.png
# 1015.png
# 1016.png
# 1017.png
# 1018.png
# 1020.png
# 1023.png
# 1024.png
# 1025.png
# Error in file1025.png
# 1026.png
# Error in file1026.png
# 1027.png
# Error in file1027.png
# 1028.png
# Error in file1028.png
# 1029.png
# Error in file1029.png
# 1030.png
# Error in file1030.png
# 1031.png
# Error in file1031.png
# 1032.png
# Error in file1032.png
# 1033.png
# Error in file1033.png
# 1034.png
# Error in file1034.png
# 1035.png
# Error in file1035.png
# 1036.png
# Error in file1036.png
# 1037.png
# Error in file1037.png
# 1038.png
# Error in file1038.png
# 1039.png
# Error in file1039.png
# 1040.png
# Error in file1040.png
# 1041.png
# Error in file1041.png
# 1042.png
# Error in file1042.png
# 1043.png
# Error in file1043.png
# 1044.png
# Error in file1044.png
# 1045.png
# Error in file1045.png
# 1046.png
# ...
